# %% [markdown]
# # Feature Engineering
#
# Thanks to our findings utilizing different classification models to predict churn, we have an idea about which features are most impactful, as well as some ideas on how to manipulate those features to improve our model's predictive capabilities.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
churn_df = pd.read_csv('./data/clean_churn.csv')
churn_df = churn_df.set_index('customerID')
churn_df.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       1              0        1           0       1             0
# 5575-GNVDE       0              0        0           0      34             1
# 3668-QPYBK       0              0        0           0       2             1
# 7795-CFOCW       0              0        0           0      45             0
# 9237-HQITU       1              0        0           0       2             1
#
#             OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  ...  \
# customerID                                                               ...
# 7590-VHVEG               1             2                 1            1  ...
# 5575-GNVDE               2             1                 2            1  ...
# 3668-QPYBK               2             2                 1            1  ...
# 7795-CFOCW               2             1                 2            2  ...
# ...

# %% [markdown]
# We are going to combine several features in order to simplify our dataset for both our model and our end interpretability.
